# %% [markdown]
# # Tensorflow Runtime Backup

# %% [markdown]
# # PyTorch Implementation

# %%
# !git clone https://github.com/Marvel0usx/high-fidelity-generative-compression.git

# %%
import sys, os
HIFIC_SOURCE = "/kaggle/working/high-fidelity-generative-compression/"
sys.path.insert(1, HIFIC_SOURCE)

# %%
# !cd /kaggle/working/high-fidelity-generative-compression; pip install -r ./requirements.txt

# %% [markdown]
# ### Download Pre-trained model for testing

# %%
# !wget https://zenodo.org/record/4026003/files/hific_med.pt
# !wget https://zenodo.org/record/4026003/files/hific_low.pt

# %%
# !wget "https://storage.googleapis.com/hific/kodak/images/originals/kodim12.png" -O /kaggle/working/high-fidelity-generative-compression/data/originals/test2.jpg

# %%
# !wget "https://www.narcity.com/media-library/image.jpg?id=25902347&width=1245&height=700&coordinates=0%2C245%2C0%2C245" -O /kaggle/working/high-fidelity-generative-compression/data/originals/test.jpg

# %%
# !ls /kaggle/working/high-fidelity-generative-compression/data/originals/

# %%
# !rm -rf /kaggle/working/high-fidelity-generative-compression/data/originals/logs

# %%
from IPython.display import Image
Image(filename="/kaggle/working/high-fidelity-generative-compression/data/originals/test2.jpg")

# %%
# !ls /kaggle/working/data/reconstructions

# %%
Image(filename="/kaggle/working/data/reconstructions/test2_RECON_0.106bpp.png")

# %%
# !python3 /kaggle/working/high-fidelity-generative-compression/compress.py -i /kaggle/working/high-fidelity-generative-compression/data/originals/ -ckpt /kaggle/working/hific_low.pt --reconstruct

# %% [markdown]
# ## Test Training

# %%
# !cd /kaggle/working/high-fidelity-generative-compression; python3 train.py --model_type compression --regime low --n_steps 1
